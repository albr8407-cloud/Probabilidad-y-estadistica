# %% [markdown]
# <a href="https://colab.research.google.com/github/albr8407-cloud/Probabilidad-y-Estadistica/blob/main/UNIDAD1/PROU1_Practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Probabilidad y Estadistica
# ##Unidad 1
# #Facilitador: Jose Gabriel Rodriguez Silva
# #Alumno: Bryan Arellano Perdue
# ##Practica 3 tabla de frecuencias

# %%
# basado en el LIBRO DE estadistica para administracion pagina 12
# creamos una lista  vacia que representa la edad de 100 personas
import random
edades = []
# Hacemos un ciclo para generar 100 numeros aleatorios que representan la edad de las p
for i in range(100):
  # genetramos un numero aleatorio con la funcion randint y lo guardamos en la variable
  # numero_aleatorio
  numero_aleatorio = random.randint( 10, 70)
  # Agregamos el numero aleatorio a la lista de valores
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [26, 58, 68, 50, 28, 51, 50, 11, 64, 52, 52, 43, 12, 54, 40, 64, 54, 37, 52, 30, 53, 29, 16, 18, 62, 53, 36, 35, 65, 11, 44, 41, 54, 51, 57, 59, 43, 29, 51, 49, 12, 58, 20, 48, 35, 31, 43, 50, 30, 28, 39, 14, 54, 43, 46, 41, 24, 14, 60, 38, 64, 50, 49, 54, 52, 58, 16, 39, 32, 60, 59, 52, 35, 25, 58, 36, 10, 17, 29, 61, 25, 64, 25, 67, 41, 55, 56, 23, 34, 21, 29, 57, 13, 39, 36, 65, 48, 49, 59, 52]

# %%
import pandas as pd ;

# %%
#Crear un dataFrame de pandas con los numeros aleatorios
df = pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    26
# 1    58
# 2    68
# 3    50
# 4    28

# %%
# Calcular la tabla de distribucion de frecuencias
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')

# Imprimir la tabla de distribucion de frecuencias
print("Tabla de distribucion de Frecuencias")
tabla_frecuencias
# Out:
# Tabla de distribucion de Frecuencias
#     Edad  Frecuencia
# 39    10           1
# 23    11           2
# 21    12           2
# 48    13           1
# 17    14           2
# 20    16           2
# 40    17           1
# 32    18           1
# 34    20           1
# 47    21           1
# 45    23           1
# 35    24           1
# 10    25           3
# 28    26           1
# 22    28           2
# 6     29           4
# 15    30           2
# 33    31           1
# 38    32           1
# 46    34           1
# 13    35           3
# 8     36           3
# 29    37           1
# 37    38           1
# 11    39           3
# 26    40           1
# 14    41           3
# 2     43           4
# 31    44           1
# 36    46           1
# 18    48           2
# 12    49           3
# 5     50           4
# 7     51           3
# 0     52           6
# 16    53           2
# 1     54           5
# 43    55           1
# 44    56           1
# 19    57           2
# 4     58           4
# 9     59           3
# 25    60           2
# 41    61           1
# 30    62           1
# 3     64           4
# 24    65           2
# 42    67           1
# 27    68           1

# %%
tabla_frecuencias['Frec Relativa'] = tabla_frecuencias['Frecuencia']/ 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 39    10           1           0.01
# 23    11           2           0.02
# 21    12           2           0.02
# 48    13           1           0.01
# 17    14           2           0.02
# 20    16           2           0.02
# 40    17           1           0.01
# 32    18           1           0.01
# 34    20           1           0.01
# 47    21           1           0.01
# 45    23           1           0.01
# 35    24           1           0.01
# 10    25           3           0.03
# 28    26           1           0.01
# 22    28           2           0.02
# 6     29           4           0.04
# 15    30           2           0.02
# 33    31           1           0.01
# 38    32           1           0.01
# 46    34           1           0.01
# 13    35           3           0.03
# 8     36           3           0.03
# 29    37           1           0.01
# 37    38           1           0.01
# 11    39           3           0.03
# 26    40           1           0.01
# 14    41           3           0.03
# 2     43           4           0.04
# 31    44           1           0.01
# 36    46           1           0.01
# 18    48           2           0.02
# 12    49           3           0.03
# 5     50           4           0.04
# 7     51           3           0.03
# 0     52           6           0.06
# 16    53           2           0.02
# 1     54           5           0.05
# 43    55           1           0.01
# 44    56           1           0.01
# 19    57           2           0.02
# 4     58           4           0.04
# 9     59           3           0.03
# 25    60           2           0.02
# 41    61           1           0.01
# 30    62           1           0.01
# 3     64           4           0.04
# 24    65           2           0.02
# 42    67           1           0.01
# 27    68           1           0.01

# %%
tabla_frecuencias['Frec Porcentual'] = tabla_frecuencias['Frecuencia']/ 100 * 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual
# 39    10           1           0.01              1.0
# 23    11           2           0.02              2.0
# 21    12           2           0.02              2.0
# 48    13           1           0.01              1.0
# 17    14           2           0.02              2.0
# 20    16           2           0.02              2.0
# 40    17           1           0.01              1.0
# 32    18           1           0.01              1.0
# 34    20           1           0.01              1.0
# 47    21           1           0.01              1.0
# 45    23           1           0.01              1.0
# 35    24           1           0.01              1.0
# 10    25           3           0.03              3.0
# 28    26           1           0.01              1.0
# 22    28           2           0.02              2.0
# 6     29           4           0.04              4.0
# 15    30           2           0.02              2.0
# 33    31           1           0.01              1.0
# 38    32           1           0.01              1.0
# 46    34           1           0.01              1.0
# 13    35           3           0.03              3.0
# 8     36           3           0.03              3.0
# 29    37           1           0.01              1.0
# 37    38           1           0.01              1.0
# 11    39           3           0.03              3.0
# 26    40           1           0.01              1.0
# 14    41           3           0.03              3.0
# 2     43           4           0.04              4.0
# 31    44           1           0.01              1.0
# 36    46           1           0.01              1.0
# 18    48           2           0.02              2.0
# 12    49           3           0.03              3.0
# 5     50           4           0.04              4.0
# 7     51           3           0.03              3.0
# 0     52           6           0.06              6.0
# 16    53           2           0.02              2.0
# 1     54           5           0.05              5.0
# 43    55           1           0.01              1.0
# 44    56           1           0.01              1.0
# 19    57           2           0.02              2.0
# 4     58           4           0.04              4.0
# 9     59           3           0.03              3.0
# 25    60           2           0.02              2.0
# 41    61           1           0.01              1.0
# 30    62           1           0.01              1.0
# 3     64           4           0.04              4.0
# 24    65           2           0.02              2.0
# 42    67           1           0.01              1.0
# 27    68           1           0.01              1.0

# %%
tabla_frecuencias['Frec Acumulada'] = tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 39    10           1           0.01              1.0               1
# 23    11           2           0.02              2.0               3
# 21    12           2           0.02              2.0               5
# 48    13           1           0.01              1.0               6
# 17    14           2           0.02              2.0               8
# 20    16           2           0.02              2.0              10
# 40    17           1           0.01              1.0              11
# 32    18           1           0.01              1.0              12
# 34    20           1           0.01              1.0              13
# 47    21           1           0.01              1.0              14
# 45    23           1           0.01              1.0              15
# 35    24           1           0.01              1.0              16
# 10    25           3           0.03              3.0              19
# 28    26           1           0.01              1.0              20
# 22    28           2           0.02              2.0              22
# 6     29           4           0.04              4.0              26
# 15    30           2           0.02              2.0              28
# 33    31           1           0.01              1.0              29
# 38    32           1           0.01              1.0              30
# 46    34           1           0.01              1.0              31
# 13    35           3           0.03              3.0              34
# 8     36           3           0.03              3.0              37
# 29    37           1           0.01              1.0              38
# 37    38           1           0.01              1.0              39
# 11    39           3           0.03              3.0              42
# 26    40           1           0.01              1.0              43
# 14    41           3           0.03              3.0              46
# 2     43           4           0.04              4.0              50
# 31    44           1           0.01              1.0              51
# 36    46           1           0.01              1.0              52
# 18    48           2           0.02              2.0              54
# 12    49           3           0.03              3.0              57
# 5     50           4           0.04              4.0              61
# 7     51           3           0.03              3.0              64
# 0     52           6           0.06              6.0              70
# 16    53           2           0.02              2.0              72
# 1     54           5           0.05              5.0              77
# 43    55           1           0.01              1.0              78
# 44    56           1           0.01              1.0              79
# 19    57           2           0.02              2.0              81
# 4     58           4           0.04              4.0              85
# 9     59           3           0.03              3.0              88
# 25    60           2           0.02              2.0              90
# 41    61           1           0.01              1.0              91
# 30    62           1           0.01              1.0              92
# 3     64           4           0.04              4.0              96
# 24    65           2           0.02              2.0              98
# 42    67           1           0.01              1.0              99
# 27    68           1           0.01              1.0             100

# %%
# Importamos la libreria math de funciones matematicas
import math

# %%
# Volvamos a usar la lista de edades
print(edades)
# Out:
# [26, 58, 68, 50, 28, 51, 50, 11, 64, 52, 52, 43, 12, 54, 40, 64, 54, 37, 52, 30, 53, 29, 16, 18, 62, 53, 36, 35, 65, 11, 44, 41, 54, 51, 57, 59, 43, 29, 51, 49, 12, 58, 20, 48, 35, 31, 43, 50, 30, 28, 39, 14, 54, 43, 46, 41, 24, 14, 60, 38, 64, 50, 49, 54, 52, 58, 16, 39, 32, 60, 59, 52, 35, 25, 58, 36, 10, 17, 29, 61, 25, 64, 25, 67, 41, 55, 56, 23, 34, 21, 29, 57, 13, 39, 36, 65, 48, 49, 59, 52]

# %%
# Crear un DataFrame con las edades
df = pd.DataFrame ({ 'Edad' : edades})
df
# Out:
#     Edad
# 0     26
# 1     58
# 2     68
# 3     50
# 4     28
# ..   ...
# 95    65
# 96    48
# 97    49
# 98    59
# 99    52
#
# [100 rows x 1 columns]

# %%
# Calcular el numero de intervalos  utilizando la regla de Sturges
n = len(edades)
K = int(1 + math.log2(n))
print("Valor de n = ", n , "\nNumero de intervalos =", K)
# Out:
# Valor de n =  100
# Numero de intervalos = 7

# %%
# Crear la tabla de frecuencia
tabla_frecuencia = pd.cut( df['Edad'], bins=K, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (51.429, 59.714]    24
# 1  (34.857, 43.143]    19
# 2  (43.143, 51.429]    14
# 3   (9.941, 18.286]    12
# 4    (59.714, 68.0]    12
# 5  (26.571, 34.857]    11
# 6  (18.286, 26.571]     8

# %%
# Ordenar la tabla de frecuencia por el intervalo
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 3   (9.941, 18.286]    12
# 6  (18.286, 26.571]     8
# 5  (26.571, 34.857]    11
# 1  (34.857, 43.143]    19
# 2  (43.143, 51.429]    14
# 0  (51.429, 59.714]    24
# 4    (59.714, 68.0]    12

# %%
# Generar columnas siguientes
tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec'] / n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec'] /n * 100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac'] = tabla_frecuencia['Frec Porc'].cumsum()

#Mostrar la tabla de frecuencia
print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 3   (9.941, 18.286]    12      0.12       12.0       12         0.12
# 6  (18.286, 26.571]     8      0.08        8.0       20         0.20
# 5  (26.571, 34.857]    11      0.11       11.0       31         0.31
# 1  (34.857, 43.143]    19      0.19       19.0       50         0.50
# 2  (43.143, 51.429]    14      0.14       14.0       64         0.64
# 0  (51.429, 59.714]    24      0.24       24.0       88         0.88
# 4    (59.714, 68.0]    12      0.12       12.0      100         1.00
#
#    Frec Porc Ac
# 3          12.0
# 6          20.0
# 5          31.0
# 1          50.0
# 2          64.0
# 0          88.0
# 4         100.0

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(edades, alpha = 0.5)
plt.title("Histograma de edades basado en la funcion de matplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funcion de matplotlib con valores estandar')

# %%
# Crear un histograma basado en la tabla de frecuencia
plt.hist(df['Edad'], bins=K, alpha= 0.5)
plt.title("Histograma de edades basado en la regla de Sturges")
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
